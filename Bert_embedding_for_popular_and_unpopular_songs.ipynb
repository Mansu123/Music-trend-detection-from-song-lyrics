# %%
import os
import torch
from transformers import BertTokenizer, BertModel
from google.colab import drive

# %%
# Mount Google Drive to access files
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# Define the path to the lyrics folder in your Google Drive
lyrics_directory = '/content/drive/MyDrive/NEUROMATCH DL/unpopular_lyrics'

# %%
# Initialize the BERT tokenizer and model
tokenizer = BertTokenizer.from_pretrained('bert-base-uncased')
model = BertModel.from_pretrained('bert-base-uncased')
# Out:
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/utils/_token.py:89: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# tokenizer_config.json:   0%|          | 0.00/48.0 [00:00<?, ?B/s]
# vocab.txt:   0%|          | 0.00/232k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/466k [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/570 [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/440M [00:00<?, ?B/s]

# %%
# Function to read lyrics from a file
def read_lyrics(file_path):
    with open(file_path, 'r', encoding='utf-8') as file:
        return file.read()

# %%
# Function to get BERT embeddings
def get_bert_embeddings(texts):
    inputs = tokenizer(texts, return_tensors='pt', padding=True, truncation=True, max_length=512)
    with torch.no_grad():
        outputs = model(**inputs)
    return outputs.last_hidden_state.mean(dim=1)  # Average embeddings

# %%
# Process each lyrics file
embeddings = []
file_paths = [os.path.join(lyrics_directory, file) for file in os.listdir(lyrics_directory) if file.endswith('.txt')]

# %%
for file_path in file_paths:
    lyrics = read_lyrics(file_path)
    embedding = get_bert_embeddings([lyrics])  # We pass a list to handle a single text input
    embeddings.append(embedding)

# %%
# Concatenate all embeddings into a single tensor
all_embeddings = torch.cat(embeddings, dim=0)

# %%
# Optional: Save embeddings to a file in Google Drive
torch.save(all_embeddings, '/content/drive/My Drive/lyrics_embeddings.pt')

# %%
print("BERT embeddings generated and saved.")
# Out:
# BERT embeddings generated and saved.

# %%
# Print the embedding for the first song
print("Embedding for the first song:", embeddings[0])
# Out:
# Embedding for the first song: tensor([[-8.4069e-02, -4.4498e-02,  4.4018e-01, -2.1197e-01,  1.8076e-01,
#           2.3916e-02,  3.8009e-01,  2.5948e-01, -1.2901e-01,  4.6508e-02,
#           9.3832e-02, -2.2220e-01, -3.6871e-01,  1.4238e-01, -2.3483e-02,
#           6.5359e-01,  2.2057e-01, -2.8473e-01, -2.4426e-01,  1.8413e-01,
#           6.9675e-01,  1.3110e-01,  1.9037e-01,  3.7568e-01,  3.4130e-01,
#           2.8082e-01, -1.4971e-01, -2.2289e-01, -2.2451e-01, -2.3374e-01,
#           3.7942e-01, -4.6079e-03, -2.6042e-01, -5.4458e-01, -1.2241e-02,
#          -6.8100e-02, -2.0799e-02, -1.1847e-01,  6.2312e-02,  1.4197e-01,
#          -5.0307e-01, -4.8403e-01, -1.9591e-01,  9.3062e-02, -3.9431e-01,
#          -3.6757e-01,  1.7180e-01,  5.5311e-02,  6.7762e-02, -9.3565e-02,
#          -1.4694e-02,  2.9622e-01, -3.4138e-01, -3.0429e-01,  1.5572e-02,
#           5.8267e-01,  2.9282e-01, -4.6675e-01, -3.9748e-01, -2.8853e-01,
#           1.2198e-01, -2.0436e-01,  5.1909e-01, -6.0413e-02, -4.1458e-02,
#           1.5776e-01, -2.1709e-01,  6.0817e-01, -6.8360e-01, -1.2544e-01,
#          -1.4274e-01, -1.2439e-01,  7.0902e-02,  4.7418e-02,  4.1623e-02,
#          -1.5617e-01,  9.6826e-03,  3.4551e-01, -4.5641e-02,  4.2958e-01,
#          -1.0484e-01,  9.5869e-02, -2.6968e-01,  6.4526e-01, -3.3763e-03,
#          -2.4232e-01, -1.0619e-01,  2.7206e-01, -3.5790e-01,  6.3937e-01,
#           1.3323e-01, -3.6159e-01,  5.2133e-02,  5.8303e-02,  3.3300e-01,
#          -7.8041e-03,  1.9029e-01,  3.6549e-01,  1.1009e-01,  1.7783e-01,
#           1.7457e-01, -4.1386e-01,  2.8065e-01, -7.0034e-02, -4.3340e-01,
#          -1.6693e-01,  2.1947e-01,  1.0050e-01, -1.4089e-01,  1.1377e-01,
#           2.0567e-01, -1.9087e-01, -2.1075e-02, -3.8721e-01,  1.8128e-01,
#          -1.3092e-01,  3.2907e-01,  2.1804e-02,  1.1598e-01,  7.0110e-02,
#          -9.1499e-03, -4.4990e-02,  3.7245e-01,  4.1684e-01,  1.4662e-01,
#           1.4239e-01, -3.1944e-01,  2.7891e-01, -4.9433e-02, -3.8555e-02,
#           2.8971e-01,  1.2270e-01, -3.4794e-02, -1.8617e-01, -1.6965e-01,
#          -5.6908e-02, -1.3581e-01, -3.1644e-01, -1.6824e-01, -1.0002e-01,
#           5.6623e-02, -3.1535e-01,  5.7134e-02,  1.7090e-01, -1.2958e-01,
#          -1.4694e-01, -3.2342e-01, -2.4252e-01,  1.0642e-01,  5.2898e-01,
#           9.1301e-02,  2.7807e-02,  2.3670e-01, -1.5749e-01, -2.5831e-01,
#          -1.0014e-02, -5.9429e-01,  1.2069e-01, -1.3813e-01,  9.2779e-02,
#           1.9659e-01,  4.8368e-02,  1.1134e-01,  4.5294e-01,  3.3741e-01,
#          -3.8315e-01, -8.6501e-02,  2.8225e-02, -3.4841e-01, -1.1017e-02,
#           9.4445e-02, -1.6950e-01,  8.7123e-01,  1.7184e-01,  1.9196e-01,
#          -5.8295e-02,  4.0534e-01, -5.0175e-02,  9.5586e-02,  4.7359e-03,
#          -8.1010e-01,  1.9838e-01,  1.0874e-01,  1.4227e-01,  8.4677e-02,
#          -6.0472e-02,  3.7292e-01, -3.8577e-01,  1.7256e-01,  4.8529e-02,
#          -1.7855e-01, -3.5957e-01, -1.8874e-02, -2.6657e-02,  3.4037e-01,
#          -3.9524e-01, -8.9400e-02, -3.8079e-01, -3.4049e-01, -5.5741e-02,
#           1.1152e-01, -1.3415e-01,  4.0818e-01,  1.3378e-01, -2.3297e-01,
#           4.6039e-02, -2.9482e-02, -9.2836e-02, -1.8073e-01,  3.6278e-01,
#           3.5072e-02,  1.4557e-02,  1.5374e-02,  2.6773e-02, -1.6534e-01,
#          -3.8488e-03,  1.4599e-01, -4.6127e-02,  2.6811e-01, -5.6996e-03,
#           1.6435e-01,  1.2292e-01, -4.0455e-01,  4.1426e-01, -8.6035e-02,
#           9.7643e-01,  2.1365e-01, -7.8271e-01,  3.0182e-01,  7.7864e-02,
#          -7.4138e-02, -3.0101e-01,  3.9152e-01, -2.8306e-01, -4.2816e-02,
#           3.4084e-01,  1.2899e-02, -8.7158e-02,  5.9623e-02, -2.8689e-01,
#          -2.4324e-01,  5.6665e-01,  3.6359e-01,  1.0486e-01, -7.2147e-02,
#          -3.9084e-02, -7.2446e-02, -3.4518e-01, -3.4288e-01, -3.3395e-01,
#          -4.0101e-01,  3.5376e-02, -5.9046e-02, -5.9982e-01, -2.2060e-02,
#          -3.8381e-01, -1.1077e-01, -3.5666e-01,  1.5058e-01, -2.6625e-01,
#           4.6015e-01,  1.3779e-01, -5.1065e-03,  1.1001e-01, -2.0226e-01,
#          -2.5563e-01, -2.8755e-01,  4.1388e-01,  2.5442e-01, -2.5475e-03,
#           1.5998e-01,  3.3112e-01,  2.4943e-01,  5.4011e-01, -2.8819e-01,
#          -1.2710e-01,  4.3328e-01,  2.3290e-01, -1.0771e-01, -3.3256e-01,
#           1.4514e-04,  3.8327e-01, -5.3308e-01,  3.9059e-02,  6.1752e-02,
#          -1.2075e-01,  3.9418e-01,  2.9182e-01, -2.3387e-01, -1.6903e-01,
#           1.1222e-01, -1.6232e-01, -3.2933e-01, -1.1599e-01,  3.6845e-01,
#           4.6177e-05,  1.6885e-02,  5.7982e-02,  1.0853e-01, -1.5053e-01,
#          -8.2028e-02,  1.9724e-02,  6.4257e-02,  2.0634e-01,  1.4611e-01,
#          -2.1535e-01, -1.5095e-01, -4.0951e-01, -3.1112e+00, -8.8378e-02,
#           3.9330e-01, -2.3410e-01,  4.1438e-01, -3.0327e-01, -5.9782e-02,
#          -1.3615e-01, -4.7641e-01,  1.0136e-01,  9.7500e-02, -4.0525e-01,
#           2.5002e-01, -2.0020e-01,  4.1443e-01, -1.1757e-01, -2.4578e-01,
#          -4.5685e-01, -1.7185e-01,  4.4247e-01, -1.8886e-01, -7.6744e-02,
#           3.6864e-01,  3.6859e-03,  4.8479e-01,  5.0743e-01,  2.5038e-02,
#          -1.6918e-01, -2.4046e-01,  1.3292e-01, -3.1118e-01, -1.0661e-01,
#          -1.5318e-01,  2.5016e-01,  4.8560e-04,  2.8685e-02,  2.0212e-01,
#          -6.4903e-01, -5.5279e-01, -3.3380e-01,  3.9427e-02, -9.1977e-01,
#          -1.8530e-01, -4.0761e-01,  4.9964e-01, -5.5148e-02, -2.9292e-01,
#          -4.5285e-01,  1.7664e-01,  1.2739e-01, -8.2935e-02, -2.1170e-01,
#          -3.5278e-01, -1.2832e-01,  1.0335e-01, -1.9611e-01,  3.1092e-01,
#           6.6634e-01, -7.6149e-02, -3.5647e-01,  1.9300e-01, -1.4377e-02,
#          -5.5657e-01, -1.8808e-01, -4.2176e-03, -2.0814e-01, -3.8738e-02,
#           9.6219e-02,  1.8870e-01,  4.0065e-02, -9.2580e-02,  3.6522e-01,
#          -4.3272e-01, -2.6825e-01, -8.1404e-02,  1.6609e-01,  9.3601e-02,
#          -8.1993e-02, -1.4790e-01,  9.8205e-02, -1.1106e-01, -4.3065e-01,
#           3.2425e-01,  3.4974e-02, -4.1002e-01, -5.6550e-01, -1.5799e-01,
#          -2.8710e-01, -2.2281e-01, -2.8033e-02,  3.8247e-01,  2.9033e-02,
#          -6.0537e-02,  1.5890e-02,  4.3866e-01, -2.1272e-02,  2.9481e-01,
#          -3.0752e-01,  2.5668e-01, -4.7047e-01,  2.0901e-01,  2.0173e-01,
#           5.3515e-01, -3.1053e-01,  1.6439e-01, -1.1385e-01, -3.3506e-01,
#           3.5025e-01, -3.5668e-01,  1.2943e-01,  8.9428e-02, -4.6778e-01,
#           2.6017e-01, -3.0255e-01, -2.6903e-01, -4.2822e-01,  1.9513e-01,
#           6.9397e-01, -3.2378e-01, -1.2193e-01, -2.3081e-01,  4.5075e-01,
#          -2.4629e-01, -5.6538e-01, -3.5165e-01,  1.3485e-01, -1.1855e-01,
#           3.2156e-01,  1.9703e-02,  3.2253e-01, -1.4160e-01, -2.1913e-01,
#          -6.0043e-02,  6.1089e-02,  6.5207e-02, -1.0378e-01,  2.7667e-02,
#          -4.8117e-01,  6.7181e-02,  1.8930e-01,  3.0981e-02,  1.5531e-01,
#           2.2322e-01,  1.3228e-02, -1.9722e-01,  4.9841e-01,  4.1390e-03,
#          -2.1753e-01, -2.3891e-01,  3.2936e-01, -4.8633e-01, -4.8367e-01,
#          -2.0317e-02, -2.9619e-01,  1.8376e-01,  3.2564e-01,  1.1152e-01,
#          -1.5484e-01, -1.8447e-01, -5.3925e-01,  1.9918e-01, -1.5283e-01,
#           4.0359e-02,  1.7912e-01,  3.4054e-02,  4.9035e-01,  1.5822e-01,
#          -1.5164e-01,  2.4239e-03, -3.9687e-02, -2.6889e-01, -1.7324e-01,
#          -1.9034e-01, -8.5139e-02, -3.4774e-01,  5.9080e-01,  4.9323e-02,
#          -1.8212e-01, -7.6321e-02,  2.0382e-01,  1.2932e-01,  1.1106e-01,
#          -1.8373e-01, -9.2707e-02,  4.0301e-01, -1.8971e-01,  2.5861e-01,
#          -3.2783e-01,  1.1943e-01,  3.2004e-01,  2.1035e-01,  3.5567e-01,
#          -4.8213e-02,  1.7495e-01, -1.6176e-01, -2.1169e-01,  3.2474e-01,
#          -2.8769e-01, -1.0807e-01,  3.5198e-01,  2.9315e-01, -2.5304e-01,
#          -4.1048e-01,  1.7698e-01,  1.4818e-01, -3.0869e-01,  3.1207e-01,
#           3.6389e-01,  2.7890e-01,  1.2224e-01, -3.1091e-01, -4.1620e-01,
#          -2.6204e-01,  4.9615e-02,  4.0164e-02, -8.1094e-01,  1.6051e-01,
#          -1.0534e-01, -4.2822e-01, -2.3954e-01, -9.7440e-02, -3.0626e-01,
#          -3.1595e-01, -2.0550e-02, -7.2422e-01,  5.0911e-02, -2.7664e-01,
#          -1.1096e-01, -1.8248e-02, -1.3262e-02,  1.5678e-01, -8.4654e-01,
#          -2.4849e-02,  3.8710e-01, -3.0882e-01,  2.9859e-01,  1.2708e-01,
#          -3.4379e-01,  8.2309e-03, -4.6371e-02,  1.3162e-01,  2.3933e-01,
#          -9.1074e-02, -1.5404e-01,  3.7151e-01,  1.9147e-01,  7.5555e-02,
#           2.0852e-01,  1.5380e-02,  3.5507e-01,  2.9773e-01,  8.2028e-02,
#           1.6861e-02, -3.2041e-01,  8.0838e-02, -3.8049e-01, -5.0638e-01,
#           2.3639e-01, -6.1128e-02,  6.4122e-03, -1.2294e-01, -2.9854e-01,
#           1.6890e-03, -2.7532e-01,  5.1828e-02,  5.0961e-02, -6.6309e-02,
#          -5.5020e-02, -1.8522e-02, -3.6041e-01, -2.5608e-02, -5.2092e-01,
#           4.5467e-03, -1.2220e-01, -2.7617e-02,  1.1213e-01, -2.3519e-01,
#          -1.0756e-01,  4.1154e-01, -5.5053e-01, -3.4569e-01, -6.2170e-02,
#          -3.6793e-01, -4.5925e-02,  3.6489e-01, -1.4383e-01,  1.9153e-01,
#           3.3686e-01, -2.1615e-01,  6.6921e-03,  3.7955e-01,  1.9422e-01,
#           2.9067e-05,  3.4979e-02, -2.6437e-01,  4.2620e-02,  5.4508e-01,
#           3.5258e-01,  5.1386e-02,  1.3984e-01, -1.2579e-03, -1.2749e-01,
#           1.8608e-01,  1.9435e-01, -2.1794e-02,  8.7152e-02,  3.4005e-01,
#          -5.6173e-01,  1.5838e-01,  3.4755e-01, -1.9949e-01, -3.3138e-01,
#           7.1401e-01,  9.1704e-02, -2.6869e-01, -2.9061e-01,  3.9080e-01,
#          -1.7905e-02, -5.4727e-02, -1.7727e-01,  2.1563e-01,  6.4556e-02,
#           7.7910e-01,  1.0696e-01,  5.7536e-01,  2.9865e-01, -1.8974e-01,
#           2.7900e-02,  1.1311e-02,  4.2351e-01, -1.2604e-01,  3.1593e-01,
#          -3.3698e-01,  5.8905e-01, -1.5313e-02,  2.2417e-01, -3.6434e-02,
#          -2.8354e-01,  1.9153e-01, -1.4972e-01, -2.3520e-01,  2.2470e-01,
#           2.1306e-01,  4.9961e-01,  5.1013e-01,  2.5387e-01,  2.6670e-01,
#          -3.9137e-01,  9.1428e-01,  5.2963e-01,  9.7050e-03,  3.8558e-01,
#          -3.6872e-02, -2.1054e-01,  2.0178e-01,  4.7534e-01,  1.9776e-01,
#           2.2941e-01, -1.0740e-01,  4.3175e-01,  1.8276e-01,  2.6665e-01,
#           3.4499e-01, -3.6939e-01, -2.4408e-01, -5.4723e-02,  1.9572e-01,
#          -2.1135e-01, -3.1796e-01,  2.0768e-01,  6.5536e-02,  2.0773e-01,
#          -1.9262e-01,  2.8867e-03, -4.0861e-01,  2.0698e-01,  7.3657e-02,
#          -5.8996e-02, -4.4657e-01,  3.8401e-01, -1.6782e-01,  2.7547e-02,
#          -5.5214e-01, -2.2897e-01, -1.6644e-02, -3.6660e-01, -2.9379e-01,
#           9.6006e-02, -4.5122e-01, -1.1820e-01, -1.5954e-01, -1.8933e-01,
#          -2.1078e-01, -4.9211e-01, -1.8369e-02, -5.8849e-01,  4.6115e-01,
#           2.1551e-01,  4.3271e-01,  2.6422e-01,  3.1150e-01, -1.3016e-01,
#          -4.5769e-01,  1.0435e-01,  1.0647e-01,  3.5646e-02, -1.9796e-01,
#           2.6087e-01,  1.4793e-01,  4.0938e-01, -4.4413e-02,  1.4410e-01,
#          -5.5283e-01,  1.1606e-01, -3.9421e-01, -1.2795e-01,  1.8314e-01,
#          -5.2895e-03, -3.9624e-01,  1.6269e-01, -3.1739e-01, -3.9127e-01,
#          -1.0668e-01,  2.6272e-01, -1.2730e-01,  4.7319e-02,  3.5367e-01,
#           3.9557e-01, -3.1302e-01, -1.7736e-01,  2.1764e-01,  1.5429e-01,
#           1.3864e-01, -4.6847e-01, -1.7092e-01, -1.9578e-01, -1.6566e-01,
#          -4.2893e-02, -3.8304e-01,  2.3617e-01,  5.1705e-01,  2.9379e-02,
#          -1.9748e-01, -3.7625e-02,  3.9115e-01, -1.6117e-01, -8.1836e-02,
#          -4.3174e-01,  6.6292e-02, -2.1670e-01, -4.8136e-01, -2.6408e-01,
#           2.3730e-02, -1.3913e-01, -3.4501e-01, -7.5205e-02, -2.3263e-01,
#          -9.4972e-02,  7.3035e-02, -8.3914e-02]])

# %% [markdown]
# #Cosine similarity from last two words from each line of lyrics

# %%
from sklearn.metrics.pairwise import cosine_similarity
import numpy as np

# %%
# Function to extract last two words from each line of lyrics
def extract_last_two_words(lines):
    last_two_words = []
    for line in lines:
        words = line.strip().split()
        if len(words) >= 2:
            last_two_words.append(' '.join(words[-2:]))
    return last_two_words

# %%
# Process each lyrics file and extract last two words
last_two_words_list = []
file_paths = [os.path.join(lyrics_directory, file) for file in os.listdir(lyrics_directory) if file.endswith('.txt')]

# %%
for file_path in file_paths:
    lyrics = read_lyrics(file_path)
    lines = lyrics.splitlines()
    last_two_words = extract_last_two_words(lines)
    last_two_words_list.extend(last_two_words)

# %%
# Get embeddings for the last two words of each line
embeddings = get_bert_embeddings(last_two_words_list)

# %%
# Calculate cosine similarities between embeddings
similarities = cosine_similarity(embeddings)

# %%
# Function to find and display similar patterns
def find_similar_patterns(similarity_matrix, texts, threshold=0.9):
    similar_pairs = []
    for i in range(len(texts)):
        for j in range(i + 1, len(texts)):
            if similarity_matrix[i, j] > threshold:
                similar_pairs.append((texts[i], texts[j], similarity_matrix[i, j]))
    return similar_pairs

# %%
# Find similar patterns with a similarity threshold (e.g., 0.9)
similar_patterns = find_similar_patterns(similarities, last_two_words_list, threshold=0.9)

# %%
# Display similar patterns
for pair in similar_patterns:
    print(f"'{pair[0]}' and '{pair[1]}' are similar with a similarity score of {pair[2]:.2f}")
# Out:
# Streaming output truncated to the last 5000 lines.
# 'the storm' and 'the rain' are similar with a similarity score of 0.95
# 'the storm' and 'the wind' are similar with a similarity score of 0.94
# 'the storm' and 'the lightning' are similar with a similarity score of 0.97
# 'me so' and 'me now' are similar with a similarity score of 0.92
# 'me so' and 'me now' are similar with a similarity score of 0.92
# 'me so' and 'me now' are similar with a similarity score of 0.92
# 'me so' and 'me caí' are similar with a similarity score of 0.92
# 'me so' and 'me now' are similar with a similarity score of 0.92
# 'me so' and 'me now' are similar with a similarity score of 0.92
# 'me so' and 'me crazy' are similar with a similarity score of 0.91
# 'your nose' and 'your skeleton' are similar with a similarity score of 0.92
# 'your nose' and 'your toes' are similar with a similarity score of 0.91
# 'your nose' and 'your toes' are similar with a similarity score of 0.91
# 'your nose' and 'your toes' are similar with a similarity score of 0.91
# 'your nose' and 'your toes' are similar with a similarity score of 0.91
# 'your nose' and 'your face' are similar with a similarity score of 0.90
# 'your nose' and 'your face' are similar with a similarity score of 0.90
# 'your nose' and 'your face' are similar with a similarity score of 0.90
# 'gonna spy' and 'gonna fly' are similar with a similarity score of 0.94
# 'gonna spy' and 'gonna die' are similar with a similarity score of 0.90
# 'gonna spy' and 'gonna fly' are similar with a similarity score of 0.94
# 'to fly' and 'to fly' are similar with a similarity score of 1.00
# 'to fly' and 'to blow' are similar with a similarity score of 0.91
# 'to fly' and 'to climb' are similar with a similarity score of 0.94
# 'to fly' and 'to dance' are similar with a similarity score of 0.91
# 'to ninety-two' and 'to ninety-two' are similar with a similarity score of 1.00
# 'to you' and 'to you' are similar with a similarity score of 1.00
# 'to you' and 'to you' are similar with a similarity score of 1.00
# 'to you' and 'to you' are similar with a similarity score of 1.00
# 'lo pido' and 'que escondes' are similar with a similarity score of 0.90
# 'lo pido' and 'es relativo' are similar with a similarity score of 0.91
# 'lo pido' and 'estoy contigo' are similar with a similarity score of 0.94
# 'lo pido' and 'lo demás' are similar with a similarity score of 0.97
# 'lo pido' and 'tú estas' are similar with a similarity score of 0.92
# 'lo pido' and 'lo demás' are similar with a similarity score of 0.97
# 'lo pido' and 'tú estas' are similar with a similarity score of 0.92
# 'lo pido' and 'como tú' are similar with a similarity score of 0.91
# 'lo pido' and 'estamos juntos' are similar with a similarity score of 0.93
# 'lo pido' and 'lo demás' are similar with a similarity score of 0.97
# 'lo pido' and 'tú estas' are similar with a similarity score of 0.92
# 'lo pido' and 'lo demás' are similar with a similarity score of 0.97
# 'lo pido' and 'tú estas' are similar with a similarity score of 0.92
# 'lo pido' and 'como tú' are similar with a similarity score of 0.91
# 'lo pido' and 'encontré contigo' are similar with a similarity score of 0.92
# 'lo pido' and 'encontré contigo' are similar with a similarity score of 0.92
# 'lo pido' and 'yo consiga' are similar with a similarity score of 0.93
# 'lo pido' and 'yo consiga' are similar with a similarity score of 0.93
# 'lo pido' and 'que quiero' are similar with a similarity score of 0.93
# 'lo pido' and 'mi manera' are similar with a similarity score of 0.92
# 'lo pido' and 'hace dinero' are similar with a similarity score of 0.94
# 'lo pido' and 'yo consiga' are similar with a similarity score of 0.93
# 'lo pido' and 'yo consiga' are similar with a similarity score of 0.93
# 'lo pido' and 'tu chavo' are similar with a similarity score of 0.94
# 'lo pido' and 'es hielo' are similar with a similarity score of 0.94
# 'lo pido' and 'una asesina' are similar with a similarity score of 0.91
# 'lo pido' and 'una noche' are similar with a similarity score of 0.91
# 'lo pido' and 'te lleve' are similar with a similarity score of 0.91
# 'lo pido' and 'una noche' are similar with a similarity score of 0.91
# 'lo pido' and 'bailando sola' are similar with a similarity score of 0.93
# 'lo pido' and 'te lleve' are similar with a similarity score of 0.91
# 'lo pido' and 'a dulce' are similar with a similarity score of 0.91
# 'lo pido' and 'tu ganas' are similar with a similarity score of 0.91
# 'lo pido' and 'tu corazón' are similar with a similarity score of 0.91
# 'lo pido' and 'una noche' are similar with a similarity score of 0.91
# 'lo pido' and 'te lleve' are similar with a similarity score of 0.91
# 'lo pido' and 'te toco' are similar with a similarity score of 0.95
# 'lo pido' and 'me rozas' are similar with a similarity score of 0.92
# 'lo pido' and 'te toco' are similar with a similarity score of 0.95
# 'lo pido' and 'me rozas' are similar with a similarity score of 0.92
# 'lo pido' and 'una noche' are similar with a similarity score of 0.91
# 'lo pido' and 'te lleve' are similar with a similarity score of 0.91
# 'lo pido' and 'una noche' are similar with a similarity score of 0.91
# 'lo pido' and 'bailando sola' are similar with a similarity score of 0.93
# 'lo pido' and 'te lleve' are similar with a similarity score of 0.91
# 'lo pido' and 'se rebeló' are similar with a similarity score of 0.94
# 'lo pido' and 'la invitó' are similar with a similarity score of 0.92
# 'lo pido' and 'que falló' are similar with a similarity score of 0.92
# 'lo pido' and 'se cayó' are similar with a similarity score of 0.93
# 'lo pido' and 'está suelta' are similar with a similarity score of 0.94
# 'lo pido' and 'está suelta' are similar with a similarity score of 0.94
# 'lo pido' and 'la invitó' are similar with a similarity score of 0.92
# 'lo pido' and 'se rebeló' are similar with a similarity score of 0.94
# 'lo pido' and 'se pasa' are similar with a similarity score of 0.92
# 'lo pido' and 'una amenaza' are similar with a similarity score of 0.91
# 'lo pido' and 'está suelta' are similar with a similarity score of 0.94
# 'lo pido' and 'está suelta' are similar with a similarity score of 0.94
# 'lo pido' and 'la invitó' are similar with a similarity score of 0.92
# 'lo pido' and 'se rebeló' are similar with a similarity score of 0.94
# 'lo pido' and 'veramente tua' are similar with a similarity score of 0.90
# 'lo pido' and 'veramente tua' are similar with a similarity score of 0.90
# 'lo pido' and 'veramente tua' are similar with a similarity score of 0.90
# 'que escondes' and 'estoy contigo' are similar with a similarity score of 0.91
# 'que escondes' and 'lo demás' are similar with a similarity score of 0.91
# 'que escondes' and 'tú estas' are similar with a similarity score of 0.92
# 'que escondes' and 'lo demás' are similar with a similarity score of 0.91
# 'que escondes' and 'tú estas' are similar with a similarity score of 0.92
# 'que escondes' and 'como tú' are similar with a similarity score of 0.90
# 'que escondes' and 'lo demás' are similar with a similarity score of 0.91
# 'que escondes' and 'tú estas' are similar with a similarity score of 0.92
# 'que escondes' and 'lo demás' are similar with a similarity score of 0.91
# 'que escondes' and 'tú estas' are similar with a similarity score of 0.92
# 'que escondes' and 'como tú' are similar with a similarity score of 0.90
# 'que escondes' and 'encontré contigo' are similar with a similarity score of 0.92
# 'que escondes' and 'encontré contigo' are similar with a similarity score of 0.92
# 'que escondes' and 'que quiero' are similar with a similarity score of 0.94
# 'que escondes' and 'es hielo' are similar with a similarity score of 0.92
# 'que escondes' and 'que concurses' are similar with a similarity score of 0.93
# 'que escondes' and 'que falló' are similar with a similarity score of 0.94
# 'que escondes' and 'está suelta' are similar with a similarity score of 0.91
# 'que escondes' and 'está suelta' are similar with a similarity score of 0.91
# 'que escondes' and 'está suelta' are similar with a similarity score of 0.91
# 'que escondes' and 'está suelta' are similar with a similarity score of 0.91
# 'dices dónde' and 'hice vibrar' are similar with a similarity score of 0.91
# 'dices dónde' and 'hice vibrar' are similar with a similarity score of 0.91
# 'dices dónde' and 'hice vibrar' are similar with a similarity score of 0.91
# 'dices dónde' and 'hice vibrar' are similar with a similarity score of 0.91
# 'dices dónde' and 'hice vibrar' are similar with a similarity score of 0.91
# 'dices dónde' and 'prende, pasa' are similar with a similarity score of 0.90
# 'es relativo' and 'Y desaparece' are similar with a similarity score of 0.91
# 'es relativo' and 'lo demás' are similar with a similarity score of 0.93
# 'es relativo' and 'lo demás' are similar with a similarity score of 0.93
# 'es relativo' and 'estamos juntos' are similar with a similarity score of 0.91
# 'es relativo' and 'Y desaparece' are similar with a similarity score of 0.91
# 'es relativo' and 'lo demás' are similar with a similarity score of 0.93
# 'es relativo' and 'lo demás' are similar with a similarity score of 0.93
# 'es relativo' and 'y vida' are similar with a similarity score of 0.92
# 'es relativo' and 'y vida' are similar with a similarity score of 0.92
# 'es relativo' and 'mi manera' are similar with a similarity score of 0.91
# 'es relativo' and 'y vida' are similar with a similarity score of 0.92
# 'es relativo' and 'y vida' are similar with a similarity score of 0.92
# 'es relativo' and 'de estado' are similar with a similarity score of 0.93
# 'es relativo' and 'es hielo' are similar with a similarity score of 0.94
# 'es relativo' and 'y vida' are similar with a similarity score of 0.92
# 'es relativo' and 'te lleve' are similar with a similarity score of 0.92
# 'es relativo' and 'te lleve' are similar with a similarity score of 0.92
# 'es relativo' and 'te lleve' are similar with a similarity score of 0.92
# 'es relativo' and 'te toco' are similar with a similarity score of 0.92
# 'es relativo' and 'me rozas' are similar with a similarity score of 0.90
# 'es relativo' and 'te toco' are similar with a similarity score of 0.92
# 'es relativo' and 'me rozas' are similar with a similarity score of 0.90
# 'es relativo' and 'te lleve' are similar with a similarity score of 0.92
# 'es relativo' and 'te lleve' are similar with a similarity score of 0.92
# 'es relativo' and 'se rebeló' are similar with a similarity score of 0.91
# 'es relativo' and 'la invitó' are similar with a similarity score of 0.91
# 'es relativo' and 'está suelta' are similar with a similarity score of 0.92
# 'es relativo' and 'está dispuesta' are similar with a similarity score of 0.92
# 'es relativo' and 'está suelta' are similar with a similarity score of 0.92
# 'es relativo' and 'está dispuesta' are similar with a similarity score of 0.92
# 'es relativo' and 'la invitó' are similar with a similarity score of 0.91
# 'es relativo' and 'se rebeló' are similar with a similarity score of 0.91
# 'es relativo' and 'una amenaza' are similar with a similarity score of 0.90
# 'es relativo' and 'es piratea'o' are similar with a similarity score of 0.93
# 'es relativo' and 'está suelta' are similar with a similarity score of 0.92
# 'es relativo' and 'está dispuesta' are similar with a similarity score of 0.92
# 'es relativo' and 'está suelta' are similar with a similarity score of 0.92
# 'es relativo' and 'está dispuesta' are similar with a similarity score of 0.92
# 'es relativo' and 'la invitó' are similar with a similarity score of 0.91
# 'es relativo' and 'se rebeló' are similar with a similarity score of 0.91
# 'es relativo' and 'dentro te' are similar with a similarity score of 0.90
# 'es relativo' and 'veramente tua' are similar with a similarity score of 0.91
# 'es relativo' and 'dentro te' are similar with a similarity score of 0.90
# 'es relativo' and 'veramente tua' are similar with a similarity score of 0.91
# 'es relativo' and 'veramente tua' are similar with a similarity score of 0.91
# 'estoy contigo' and 'Y desaparece' are similar with a similarity score of 0.90
# 'estoy contigo' and 'lo demás' are similar with a similarity score of 0.92
# 'estoy contigo' and 'tú estas' are similar with a similarity score of 0.93
# 'estoy contigo' and 'lo demás' are similar with a similarity score of 0.92
# 'estoy contigo' and 'tú estas' are similar with a similarity score of 0.93
# 'estoy contigo' and 'estamos juntos' are similar with a similarity score of 0.93
# 'estoy contigo' and 'Y desaparece' are similar with a similarity score of 0.90
# 'estoy contigo' and 'lo demás' are similar with a similarity score of 0.92
# 'estoy contigo' and 'tú estas' are similar with a similarity score of 0.93
# 'estoy contigo' and 'lo demás' are similar with a similarity score of 0.92
# 'estoy contigo' and 'tú estas' are similar with a similarity score of 0.93
# 'estoy contigo' and 'encontré contigo' are similar with a similarity score of 0.94
# 'estoy contigo' and 'encontré contigo' are similar with a similarity score of 0.94
# 'estoy contigo' and 'que quiero' are similar with a similarity score of 0.92
# 'estoy contigo' and 'hace dinero' are similar with a similarity score of 0.91
# 'estoy contigo' and 'tu chavo' are similar with a similarity score of 0.92
# 'estoy contigo' and 'es hielo' are similar with a similarity score of 0.93
# 'estoy contigo' and 'una asesina' are similar with a similarity score of 0.91
# 'estoy contigo' and 'una noche' are similar with a similarity score of 0.91
# 'estoy contigo' and 'una noche' are similar with a similarity score of 0.91
# 'estoy contigo' and 'bailando sola' are similar with a similarity score of 0.91
# 'estoy contigo' and 'una noche' are similar with a similarity score of 0.91
# 'estoy contigo' and 'te toco' are similar with a similarity score of 0.93
# 'estoy contigo' and 'te toco' are similar with a similarity score of 0.93
# 'estoy contigo' and 'una noche' are similar with a similarity score of 0.91
# 'estoy contigo' and 'una noche' are similar with a similarity score of 0.91
# 'estoy contigo' and 'bailando sola' are similar with a similarity score of 0.91
# 'estoy contigo' and 'se rebeló' are similar with a similarity score of 0.94
# 'estoy contigo' and 'que falló' are similar with a similarity score of 0.91
# 'estoy contigo' and 'se cayó' are similar with a similarity score of 0.93
# 'estoy contigo' and 'está suelta' are similar with a similarity score of 0.94
# 'estoy contigo' and 'está suelta' are similar with a similarity score of 0.94
# 'estoy contigo' and 'se rebeló' are similar with a similarity score of 0.94
# 'estoy contigo' and 'se pasa' are similar with a similarity score of 0.91
# 'estoy contigo' and 'una amenaza' are similar with a similarity score of 0.90
# 'estoy contigo' and 'está suelta' are similar with a similarity score of 0.94
# 'estoy contigo' and 'está suelta' are similar with a similarity score of 0.94
# 'estoy contigo' and 'se rebeló' are similar with a similarity score of 0.94
# 'se detiene' and 'se detiene' are similar with a similarity score of 1.00
# 'se detiene' and 'que falle' are similar with a similarity score of 0.92
# 'Y desaparece' and 'los dioses' are similar with a similarity score of 0.90
# 'Y desaparece' and 'estamos juntos' are similar with a similarity score of 0.93
# 'Y desaparece' and 'Y desaparece' are similar with a similarity score of 1.00
# 'Y desaparece' and 'de encontrar' are similar with a similarity score of 0.92
# 'Y desaparece' and 'encontré contigo' are similar with a similarity score of 0.91
# 'Y desaparece' and 'de encontrar' are similar with a similarity score of 0.92
# 'Y desaparece' and 'encontré contigo' are similar with a similarity score of 0.91
# 'Y desaparece' and 'de estado' are similar with a similarity score of 0.91
# 'Y desaparece' and 'es hielo' are similar with a similarity score of 0.90
# 'Y desaparece' and 'una asesina' are similar with a similarity score of 0.92
# 'Y desaparece' and 'una noche' are similar with a similarity score of 0.91
# 'Y desaparece' and 'una noche' are similar with a similarity score of 0.91
# 'Y desaparece' and 'bailando sola' are similar with a similarity score of 0.91
# 'Y desaparece' and 'Moviendo sola' are similar with a similarity score of 0.90
# 'Y desaparece' and 'muy fuerte' are similar with a similarity score of 0.90
# 'Y desaparece' and 'una noche' are similar with a similarity score of 0.91
# 'Y desaparece' and 'te toco' are similar with a similarity score of 0.91
# 'Y desaparece' and 'te toco' are similar with a similarity score of 0.91
# 'Y desaparece' and 'una noche' are similar with a similarity score of 0.91
# 'Y desaparece' and 'una noche' are similar with a similarity score of 0.91
# 'Y desaparece' and 'bailando sola' are similar with a similarity score of 0.91
# 'Y desaparece' and 'Moviendo sola' are similar with a similarity score of 0.90
# 'Y desaparece' and '(Se aborreció)' are similar with a similarity score of 0.91
# 'Y desaparece' and 'se rebeló' are similar with a similarity score of 0.90
# 'Y desaparece' and '(Se aborreció)' are similar with a similarity score of 0.91
# 'Y desaparece' and 'la invitó' are similar with a similarity score of 0.94
# 'Y desaparece' and 'una relación' are similar with a similarity score of 0.92
# 'Y desaparece' and 'está suelta' are similar with a similarity score of 0.92
# 'Y desaparece' and 'está dispuesta' are similar with a similarity score of 0.91
# 'Y desaparece' and 'está suelta' are similar with a similarity score of 0.92
# 'Y desaparece' and 'está dispuesta' are similar with a similarity score of 0.91
# 'Y desaparece' and '(Se aborreció)' are similar with a similarity score of 0.91
# 'Y desaparece' and 'la invitó' are similar with a similarity score of 0.94
# 'Y desaparece' and 'se rebeló' are similar with a similarity score of 0.90
# 'Y desaparece' and 'una amenaza' are similar with a similarity score of 0.92
# 'Y desaparece' and 'está suelta' are similar with a similarity score of 0.92
# 'Y desaparece' and 'está dispuesta' are similar with a similarity score of 0.91
# 'Y desaparece' and 'está suelta' are similar with a similarity score of 0.92
# 'Y desaparece' and 'está dispuesta' are similar with a similarity score of 0.91
# 'Y desaparece' and '(Se aborreció)' are similar with a similarity score of 0.91
# 'Y desaparece' and 'la invitó' are similar with a similarity score of 0.94
# 'Y desaparece' and 'se rebeló' are similar with a similarity score of 0.90
# 'Y desaparece' and 'veramente tua' are similar with a similarity score of 0.91
# 'Y desaparece' and 'veramente tua' are similar with a similarity score of 0.91
# 'Y desaparece' and 'veramente tua' are similar with a similarity score of 0.91
# 'lo demás' and 'tú estas' are similar with a similarity score of 0.94
# 'lo demás' and 'lo demás' are similar with a similarity score of 1.00
# 'lo demás' and 'tú estas' are similar with a similarity score of 0.94
# 'lo demás' and 'como tú' are similar with a similarity score of 0.92
# 'lo demás' and 'estamos juntos' are similar with a similarity score of 0.93
# 'lo demás' and 'lo demás' are similar with a similarity score of 1.00
# 'lo demás' and 'tú estas' are similar with a similarity score of 0.94
# 'lo demás' and 'lo demás' are similar with a similarity score of 1.00
# 'lo demás' and 'tú estas' are similar with a similarity score of 0.94
# 'lo demás' and 'como tú' are similar with a similarity score of 0.92
# 'lo demás' and 'nada más' are similar with a similarity score of 0.91
# 'lo demás' and 'encontré contigo' are similar with a similarity score of 0.91
# 'lo demás' and 'nada más' are similar with a similarity score of 0.91
# 'lo demás' and 'encontré contigo' are similar with a similarity score of 0.91
# 'lo demás' and 'y vida' are similar with a similarity score of 0.91
# 'lo demás' and 'yo consiga' are similar with a similarity score of 0.93
# 'lo demás' and 'y vida' are similar with a similarity score of 0.91
# 'lo demás' and 'yo consiga' are similar with a similarity score of 0.93
# 'lo demás' and 'que quiero' are similar with a similarity score of 0.92
# 'lo demás' and 'mi manera' are similar with a similarity score of 0.93
# 'lo demás' and 'hace dinero' are similar with a similarity score of 0.92
# 'lo demás' and 'y vida' are similar with a similarity score of 0.91
# 'lo demás' and 'yo consiga' are similar with a similarity score of 0.93
# 'lo demás' and 'y vida' are similar with a similarity score of 0.91
# 'lo demás' and 'yo consiga' are similar with a similarity score of 0.93
# 'lo demás' and 'tu chavo' are similar with a similarity score of 0.93
# 'lo demás' and 'es hielo' are similar with a similarity score of 0.95
# 'lo demás' and 'una asesina' are similar with a similarity score of 0.90
# 'lo demás' and 'y vida' are similar with a similarity score of 0.91
# 'lo demás' and 'hice vibrar' are similar with a similarity score of 0.90
# 'lo demás' and 'te lleve' are similar with a similarity score of 0.92
# 'lo demás' and 'hice vibrar' are similar with a similarity score of 0.90
# 'lo demás' and 'bailando sola' are similar with a similarity score of 0.93
# 'lo demás' and 'te lleve' are similar with a similarity score of 0.92
# 'lo demás' and 'a dulce' are similar with a similarity score of 0.90
# 'lo demás' and 'tu ganas' are similar with a similarity score of 0.94
# 'lo demás' and 'como yo' are similar with a similarity score of 0.90
# 'lo demás' and 'como yo' are similar with a similarity score of 0.90
# 'lo demás' and 'hice vibrar' are similar with a similarity score of 0.90
# 'lo demás' and 'te lleve' are similar with a similarity score of 0.92
# 'lo demás' and 'te toco' are similar with a similarity score of 0.94
# 'lo demás' and 'me rozas' are similar with a similarity score of 0.93
# 'lo demás' and 'te excitas' are similar with a similarity score of 0.90
# 'lo demás' and 'te toco' are similar with a similarity score of 0.94
# 'lo demás' and 'me rozas' are similar with a similarity score of 0.93
# 'lo demás' and 'te excitas' are similar with a similarity score of 0.90
# 'lo demás' and 'hice vibrar' are similar with a similarity score of 0.90
# 'lo demás' and 'te lleve' are similar with a similarity score of 0.92
# 'lo demás' and 'hice vibrar' are similar with a similarity score of 0.90
# 'lo demás' and 'bailando sola' are similar with a similarity score of 0.93
# 'lo demás' and 'te lleve' are similar with a similarity score of 0.92
# 'lo demás' and 'se rebeló' are similar with a similarity score of 0.94
# 'lo demás' and 'la invitó' are similar with a similarity score of 0.90
# 'lo demás' and 'que falló' are similar with a similarity score of 0.93
# 'lo demás' and 'se cayó' are similar with a similarity score of 0.93
# 'lo demás' and 'está suelta' are similar with a similarity score of 0.93
# 'lo demás' and 'está suelta' are similar with a similarity score of 0.93
# 'lo demás' and 'la invitó' are similar with a similarity score of 0.90
# 'lo demás' and 'se rebeló' are similar with a similarity score of 0.94
# 'lo demás' and 'se pasa' are similar with a similarity score of 0.93
# 'lo demás' and 'una amenaza' are similar with a similarity score of 0.90
# 'lo demás' and 'es piratea'o' are similar with a similarity score of 0.90
# 'lo demás' and 'está suelta' are similar with a similarity score of 0.93
# 'lo demás' and 'está suelta' are similar with a similarity score of 0.93
# 'lo demás' and 'la invitó' are similar with a similarity score of 0.90
# 'lo demás' and 'se rebeló' are similar with a similarity score of 0.94
# 'lo demás' and 'veramente tua' are similar with a similarity score of 0.92
# 'lo demás' and 'veramente tua' are similar with a similarity score of 0.92
# 'lo demás' and 'veramente tua' are similar with a similarity score of 0.92
# 'tú estas' and 'lo demás' are similar with a similarity score of 0.94
# 'tú estas' and 'tú estas' are similar with a similarity score of 1.00
# 'tú estas' and 'como tú' are similar with a similarity score of 0.93
# 'tú estas' and 'estamos juntos' are similar with a similarity score of 0.91
# 'tú estas' and 'lo demás' are similar with a similarity score of 0.94
# 'tú estas' and 'tú estas' are similar with a similarity score of 1.00
# 'tú estas' and 'lo demás' are similar with a similarity score of 0.94
# 'tú estas' and 'tú estas' are similar with a similarity score of 1.00
# 'tú estas' and 'como tú' are similar with a similarity score of 0.93
# 'tú estas' and 'encontré contigo' are similar with a similarity score of 0.91
# 'tú estas' and 'encontré contigo' are similar with a similarity score of 0.91
# 'tú estas' and 'que quiero' are similar with a similarity score of 0.94
# 'tú estas' and 'tu chavo' are similar with a similarity score of 0.93
# 'tú estas' and 'es hielo' are similar with a similarity score of 0.92
# 'tú estas' and 'bailando sola' are similar with a similarity score of 0.91
# 'tú estas' and 'tu ganas' are similar with a similarity score of 0.91
# 'tú estas' and 'te toco' are similar with a similarity score of 0.92
# 'tú estas' and 'te toco' are similar with a similarity score of 0.92
# 'tú estas' and 'bailando sola' are similar with a similarity score of 0.91
# 'tú estas' and 'se rebeló' are similar with a similarity score of 0.94
# 'tú estas' and 'que falló' are similar with a similarity score of 0.93
# 'tú estas' and 'se cayó' are similar with a similarity score of 0.92
# 'tú estas' and 'está suelta' are similar with a similarity score of 0.94
# 'tú estas' and 'está suelta' are similar with a similarity score of 0.94
# 'tú estas' and 'se rebeló' are similar with a similarity score of 0.94
# 'tú estas' and 'se pasa' are similar with a similarity score of 0.95
# 'tú estas' and 'está suelta' are similar with a similarity score of 0.94
# 'tú estas' and 'está suelta' are similar with a similarity score of 0.94
# 'tú estas' and 'se rebeló' are similar with a similarity score of 0.94
# 'sólo tú' and 'como tú' are similar with a similarity score of 0.93
# 'sólo tú' and 'sólo tú' are similar with a similarity score of 1.00
# 'sólo tú' and 'como tú' are similar with a similarity score of 0.93
# 'sólo tú' and 'mi manera' are similar with a similarity score of 0.92
# 'sólo tú' and 'tu cara' are similar with a similarity score of 0.91
# 'sólo tú' and 'tu ganas' are similar with a similarity score of 0.91
# 'sólo tú' and 'veramente tua' are similar with a similarity score of 0.90
# 'sólo tú' and 'veramente tua' are similar with a similarity score of 0.90
# 'sólo tú' and 'veramente tua' are similar with a similarity score of 0.90
# 'lo demás' and 'tú estas' are similar with a similarity score of 0.94
# 'lo demás' and 'como tú' are similar with a similarity score of 0.92
# 'lo demás' and 'estamos juntos' are similar with a similarity score of 0.93
# 'lo demás' and 'lo demás' are similar with a similarity score of 1.00
# 'lo demás' and 'tú estas' are similar with a similarity score of 0.94
# 'lo demás' and 'lo demás' are similar with a similarity score of 1.00
# 'lo demás' and 'tú estas' are similar with a similarity score of 0.94
# 'lo demás' and 'como tú' are similar with a similarity score of 0.92
# 'lo demás' and 'nada más' are similar with a similarity score of 0.91
# 'lo demás' and 'encontré contigo' are similar with a similarity score of 0.91
# 'lo demás' and 'nada más' are similar with a similarity score of 0.91
# 'lo demás' and 'encontré contigo' are similar with a similarity score of 0.91
# 'lo demás' and 'y vida' are similar with a similarity score of 0.91
# 'lo demás' and 'yo consiga' are similar with a similarity score of 0.93
# 'lo demás' and 'y vida' are similar with a similarity score of 0.91
# 'lo demás' and 'yo consiga' are similar with a similarity score of 0.93
# 'lo demás' and 'que quiero' are similar with a similarity score of 0.92
# 'lo demás' and 'mi manera' are similar with a similarity score of 0.93
# 'lo demás' and 'hace dinero' are similar with a similarity score of 0.92
# 'lo demás' and 'y vida' are similar with a similarity score of 0.91
# 'lo demás' and 'yo consiga' are similar with a similarity score of 0.93
# 'lo demás' and 'y vida' are similar with a similarity score of 0.91
# 'lo demás' and 'yo consiga' are similar with a similarity score of 0.93
# 'lo demás' and 'tu chavo' are similar with a similarity score of 0.93
# 'lo demás' and 'es hielo' are similar with a similarity score of 0.95
# 'lo demás' and 'una asesina' are similar with a similarity score of 0.90
# 'lo demás' and 'y vida' are similar with a similarity score of 0.91
# 'lo demás' and 'hice vibrar' are similar with a similarity score of 0.90
# 'lo demás' and 'te lleve' are similar with a similarity score of 0.92
# 'lo demás' and 'hice vibrar' are similar with a similarity score of 0.90
# 'lo demás' and 'bailando sola' are similar with a similarity score of 0.93
# 'lo demás' and 'te lleve' are similar with a similarity score of 0.92
# 'lo demás' and 'a dulce' are similar with a similarity score of 0.90
# 'lo demás' and 'tu ganas' are similar with a similarity score of 0.94
# 'lo demás' and 'como yo' are similar with a similarity score of 0.90
# 'lo demás' and 'como yo' are similar with a similarity score of 0.90
# 'lo demás' and 'hice vibrar' are similar with a similarity score of 0.90
# 'lo demás' and 'te lleve' are similar with a similarity score of 0.92
# 'lo demás' and 'te toco' are similar with a similarity score of 0.94
# 'lo demás' and 'me rozas' are similar with a similarity score of 0.93
# 'lo demás' and 'te excitas' are similar with a similarity score of 0.90
# 'lo demás' and 'te toco' are similar with a similarity score of 0.94
# 'lo demás' and 'me rozas' are similar with a similarity score of 0.93
# 'lo demás' and 'te excitas' are similar with a similarity score of 0.90
# 'lo demás' and 'hice vibrar' are similar with a similarity score of 0.90
# 'lo demás' and 'te lleve' are similar with a similarity score of 0.92
# 'lo demás' and 'hice vibrar' are similar with a similarity score of 0.90
# 'lo demás' and 'bailando sola' are similar with a similarity score of 0.93
# 'lo demás' and 'te lleve' are similar with a similarity score of 0.92
# 'lo demás' and 'se rebeló' are similar with a similarity score of 0.94
# 'lo demás' and 'la invitó' are similar with a similarity score of 0.90
# 'lo demás' and 'que falló' are similar with a similarity score of 0.93
# 'lo demás' and 'se cayó' are similar with a similarity score of 0.93
# 'lo demás' and 'está suelta' are similar with a similarity score of 0.93
# 'lo demás' and 'está suelta' are similar with a similarity score of 0.93
# 'lo demás' and 'la invitó' are similar with a similarity score of 0.90
# 'lo demás' and 'se rebeló' are similar with a similarity score of 0.94
# 'lo demás' and 'se pasa' are similar with a similarity score of 0.93
# 'lo demás' and 'una amenaza' are similar with a similarity score of 0.90
# 'lo demás' and 'es piratea'o' are similar with a similarity score of 0.90
# 'lo demás' and 'está suelta' are similar with a similarity score of 0.93
# 'lo demás' and 'está suelta' are similar with a similarity score of 0.93
# 'lo demás' and 'la invitó' are similar with a similarity score of 0.90
# 'lo demás' and 'se rebeló' are similar with a similarity score of 0.94
# 'lo demás' and 'veramente tua' are similar with a similarity score of 0.92
# 'lo demás' and 'veramente tua' are similar with a similarity score of 0.92
# 'lo demás' and 'veramente tua' are similar with a similarity score of 0.92
# 'tú estas' and 'como tú' are similar with a similarity score of 0.93
# 'tú estas' and 'estamos juntos' are similar with a similarity score of 0.91
# 'tú estas' and 'lo demás' are similar with a similarity score of 0.94
# 'tú estas' and 'tú estas' are similar with a similarity score of 1.00
# 'tú estas' and 'lo demás' are similar with a similarity score of 0.94
# 'tú estas' and 'tú estas' are similar with a similarity score of 1.00
# 'tú estas' and 'como tú' are similar with a similarity score of 0.93
# 'tú estas' and 'encontré contigo' are similar with a similarity score of 0.91
# 'tú estas' and 'encontré contigo' are similar with a similarity score of 0.91
# 'tú estas' and 'que quiero' are similar with a similarity score of 0.94
# 'tú estas' and 'tu chavo' are similar with a similarity score of 0.93
# 'tú estas' and 'es hielo' are similar with a similarity score of 0.92
# 'tú estas' and 'bailando sola' are similar with a similarity score of 0.91
# 'tú estas' and 'tu ganas' are similar with a similarity score of 0.91
# 'tú estas' and 'te toco' are similar with a similarity score of 0.92
# 'tú estas' and 'te toco' are similar with a similarity score of 0.92
# 'tú estas' and 'bailando sola' are similar with a similarity score of 0.91
# 'tú estas' and 'se rebeló' are similar with a similarity score of 0.94
# 'tú estas' and 'que falló' are similar with a similarity score of 0.93
# 'tú estas' and 'se cayó' are similar with a similarity score of 0.92
# 'tú estas' and 'está suelta' are similar with a similarity score of 0.94
# 'tú estas' and 'está suelta' are similar with a similarity score of 0.94
# 'tú estas' and 'se rebeló' are similar with a similarity score of 0.94
# 'tú estas' and 'se pasa' are similar with a similarity score of 0.95
# 'tú estas' and 'está suelta' are similar with a similarity score of 0.94
# 'tú estas' and 'está suelta' are similar with a similarity score of 0.94
# 'tú estas' and 'se rebeló' are similar with a similarity score of 0.94
# 'como tú' and 'lo demás' are similar with a similarity score of 0.92
# 'como tú' and 'tú estas' are similar with a similarity score of 0.93
# 'como tú' and 'sólo tú' are similar with a similarity score of 0.93
# 'como tú' and 'lo demás' are similar with a similarity score of 0.92
# 'como tú' and 'tú estas' are similar with a similarity score of 0.93
# 'como tú' and 'como tú' are similar with a similarity score of 1.00
# 'como tú' and 'yo consiga' are similar with a similarity score of 0.91
# 'como tú' and 'yo consiga' are similar with a similarity score of 0.91
# 'como tú' and 'que quiero' are similar with a similarity score of 0.92
# 'como tú' and 'mi manera' are similar with a similarity score of 0.90
# 'como tú' and 'yo consiga' are similar with a similarity score of 0.91
# 'como tú' and 'yo consiga' are similar with a similarity score of 0.91
# 'como tú' and 'tu chavo' are similar with a similarity score of 0.92
# 'como tú' and 'es hielo' are similar with a similarity score of 0.92
# 'como tú' and 'tu ganas' are similar with a similarity score of 0.92
# 'como tú' and 'como yo' are similar with a similarity score of 0.91
# 'como tú' and 'como yo' are similar with a similarity score of 0.91
# 'como tú' and 'te toco' are similar with a similarity score of 0.92
# 'como tú' and 'te toco' are similar with a similarity score of 0.92
# 'como tú' and 'se rebeló' are similar with a similarity score of 0.92
# 'como tú' and 'que falló' are similar with a similarity score of 0.92
# 'como tú' and 'se cayó' are similar with a similarity score of 0.92
# 'como tú' and 'está suelta' are similar with a similarity score of 0.91
# 'como tú' and 'está suelta' are similar with a similarity score of 0.91
# 'como tú' and 'se rebeló' are similar with a similarity score of 0.92
# 'como tú' and 'se pasa' are similar with a similarity score of 0.92
# 'como tú' and 'está suelta' are similar with a similarity score of 0.91
# 'como tú' and 'está suelta' are similar with a similarity score of 0.91
# 'como tú' and 'se rebeló' are similar with a similarity score of 0.92
# 'los dioses' and 'la noche' are similar with a similarity score of 0.91
# 'los dioses' and 'estamos juntos' are similar with a similarity score of 0.90
# 'los dioses' and 'Y desaparece' are similar with a similarity score of 0.90
# 'los dioses' and 'la dema' are similar with a similarity score of 0.90
# 'los dioses' and 'de estado' are similar with a similarity score of 0.91
# 'los dioses' and 'el pelo' are similar with a similarity score of 0.90
# 'los dioses' and 'los dos' are similar with a similarity score of 0.94
# 'los dioses' and 'me rozas' are similar with a similarity score of 0.90
# 'los dioses' and 'me rozas' are similar with a similarity score of 0.90
# 'los dioses' and 'la invitó' are similar with a similarity score of 0.91
# 'los dioses' and 'la invitó' are similar with a similarity score of 0.91
# 'los dioses' and 'una amenaza' are similar with a similarity score of 0.90
# 'los dioses' and 'la invitó' are similar with a similarity score of 0.91
# 'la noche' and 'la dema' are similar with a similarity score of 0.93
# 'la noche' and 'la familia' are similar with a similarity score of 0.93
# 'la noche' and 'de estado' are similar with a similarity score of 0.90
# 'la noche' and 'una noche' are similar with a similarity score of 0.93
# 'la noche' and 'una noche' are similar with a similarity score of 0.93
# 'la noche' and 'una noche' are similar with a similarity score of 0.93
# 'la noche' and 'una noche' are similar with a similarity score of 0.93
# 'la noche' and 'una noche' are similar with a similarity score of 0.93
# 'la noche' and 'la invitó' are similar with a similarity score of 0.94
# 'la noche' and 'una relación' are similar with a similarity score of 0.91
# 'la noche' and 'la invitó' are similar with a similarity score of 0.94
# 'la noche' and 'una amenaza' are similar with a similarity score of 0.91
# 'la noche' and 'la invitó' are similar with a similarity score of 0.94
# 'la noche' and 'una strada' are similar with a similarity score of 0.90
# 'la noche' and 'la fermata' are similar with a similarity score of 0.93
# 'estamos juntos' and 'Y desaparece' are similar with a similarity score of 0.93
# 'estamos juntos' and 'lo demás' are similar with a similarity score of 0.93
# 'estamos juntos' and 'tú estas' are similar with a similarity score of 0.91
# 'estamos juntos' and 'lo demás' are similar with a similarity score of 0.93
# 'estamos juntos' and 'tú estas' are similar with a similarity score of 0.91
# 'estamos juntos' and 'encontré contigo' are similar with a similarity score of 0.92
# 'estamos juntos' and 'encontré contigo' are similar with a similarity score of 0.92
# 'estamos juntos' and 'hace dinero' are similar with a similarity score of 0.91
# 'estamos juntos' and 'de estado' are similar with a similarity score of 0.90
# 'estamos juntos' and 'es hielo' are similar with a similarity score of 0.92
# 'estamos juntos' and 'una asesina' are similar with a similarity score of 0.92
# 'estamos juntos' and 'una noche' are similar with a similarity score of 0.92
# 'estamos juntos' and 'una noche' are similar with a similarity score of 0.92
# 'estamos juntos' and 'bailando sola' are similar with a similarity score of 0.93
# 'estamos juntos' and 'a dulce' are similar with a similarity score of 0.91
# 'estamos juntos' and 'una noche' are similar with a similarity score of 0.92
# 'estamos juntos' and 'te toco' are similar with a similarity score of 0.94
# 'estamos juntos' and 'me rozas' are similar with a similarity score of 0.92
# 'estamos juntos' and 'te excitas' are similar with a similarity score of 0.93
# 'estamos juntos' and 'te toco' are similar with a similarity score of 0.94
# 'estamos juntos' and 'me rozas' are similar with a similarity score of 0.92
# 'estamos juntos' and 'te excitas' are similar with a similarity score of 0.93
# 'estamos juntos' and 'una noche' are similar with a similarity score of 0.92
# 'estamos juntos' and 'una noche' are similar with a similarity score of 0.92
# 'estamos juntos' and 'bailando sola' are similar with a similarity score of 0.93
# 'estamos juntos' and 'se rebeló' are similar with a similarity score of 0.92
# 'estamos juntos' and 'la invitó' are similar with a similarity score of 0.92
# 'estamos juntos' and 'una relación' are similar with a similarity score of 0.91
# 'estamos juntos' and 'se cayó' are similar with a similarity score of 0.91
# 'estamos juntos' and 'está suelta' are similar with a similarity score of 0.95
# 'estamos juntos' and 'está dispuesta' are similar with a similarity score of 0.90
# 'estamos juntos' and 'está suelta' are similar with a similarity score of 0.95
# 'estamos juntos' and 'está dispuesta' are similar with a similarity score of 0.90
# 'estamos juntos' and 'la invitó' are similar with a similarity score of 0.92
# 'estamos juntos' and 'se rebeló' are similar with a similarity score of 0.92
# 'estamos juntos' and 'se pasa' are similar with a similarity score of 0.90
# 'estamos juntos' and 'una amenaza' are similar with a similarity score of 0.92
# 'estamos juntos' and 'está suelta' are similar with a similarity score of 0.95
# 'estamos juntos' and 'está dispuesta' are similar with a similarity score of 0.90
# 'estamos juntos' and 'está suelta' are similar with a similarity score of 0.95
# 'estamos juntos' and 'está dispuesta' are similar with a similarity score of 0.90
# 'estamos juntos' and 'la invitó' are similar with a similarity score of 0.92
# 'estamos juntos' and 'se rebeló' are similar with a similarity score of 0.92
# 'estamos juntos' and 'veramente tua' are similar with a similarity score of 0.92
# 'estamos juntos' and 'veramente tua' are similar with a similarity score of 0.92
# 'estamos juntos' and 'veramente tua' are similar with a similarity score of 0.92
# 'se detiene' and 'que falle' are similar with a similarity score of 0.92
# 'Y desaparece' and 'de encontrar' are similar with a similarity score of 0.92
# 'Y desaparece' and 'encontré contigo' are similar with a similarity score of 0.91
# 'Y desaparece' and 'de encontrar' are similar with a similarity score of 0.92
# 'Y desaparece' and 'encontré contigo' are similar with a similarity score of 0.91
# 'Y desaparece' and 'de estado' are similar with a similarity score of 0.91
# 'Y desaparece' and 'es hielo' are similar with a similarity score of 0.90
# 'Y desaparece' and 'una asesina' are similar with a similarity score of 0.92
# 'Y desaparece' and 'una noche' are similar with a similarity score of 0.91
# 'Y desaparece' and 'una noche' are similar with a similarity score of 0.91
# 'Y desaparece' and 'bailando sola' are similar with a similarity score of 0.91
# 'Y desaparece' and 'Moviendo sola' are similar with a similarity score of 0.90
# 'Y desaparece' and 'muy fuerte' are similar with a similarity score of 0.90
# 'Y desaparece' and 'una noche' are similar with a similarity score of 0.91
# 'Y desaparece' and 'te toco' are similar with a similarity score of 0.91
# 'Y desaparece' and 'te toco' are similar with a similarity score of 0.91
# 'Y desaparece' and 'una noche' are similar with a similarity score of 0.91
# 'Y desaparece' and 'una noche' are similar with a similarity score of 0.91
# 'Y desaparece' and 'bailando sola' are similar with a similarity score of 0.91
# 'Y desaparece' and 'Moviendo sola' are similar with a similarity score of 0.90
# 'Y desaparece' and '(Se aborreció)' are similar with a similarity score of 0.91
# 'Y desaparece' and 'se rebeló' are similar with a similarity score of 0.90
# 'Y desaparece' and '(Se aborreció)' are similar with a similarity score of 0.91
# 'Y desaparece' and 'la invitó' are similar with a similarity score of 0.94
# 'Y desaparece' and 'una relación' are similar with a similarity score of 0.92
# 'Y desaparece' and 'está suelta' are similar with a similarity score of 0.92
# 'Y desaparece' and 'está dispuesta' are similar with a similarity score of 0.91
# 'Y desaparece' and 'está suelta' are similar with a similarity score of 0.92
# 'Y desaparece' and 'está dispuesta' are similar with a similarity score of 0.91
# 'Y desaparece' and '(Se aborreció)' are similar with a similarity score of 0.91
# 'Y desaparece' and 'la invitó' are similar with a similarity score of 0.94
# 'Y desaparece' and 'se rebeló' are similar with a similarity score of 0.90
# 'Y desaparece' and 'una amenaza' are similar with a similarity score of 0.92
# 'Y desaparece' and 'está suelta' are similar with a similarity score of 0.92
# 'Y desaparece' and 'está dispuesta' are similar with a similarity score of 0.91
# 'Y desaparece' and 'está suelta' are similar with a similarity score of 0.92
# 'Y desaparece' and 'está dispuesta' are similar with a similarity score of 0.91
# 'Y desaparece' and '(Se aborreció)' are similar with a similarity score of 0.91
# 'Y desaparece' and 'la invitó' are similar with a similarity score of 0.94
# 'Y desaparece' and 'se rebeló' are similar with a similarity score of 0.90
# 'Y desaparece' and 'veramente tua' are similar with a similarity score of 0.91
# 'Y desaparece' and 'veramente tua' are similar with a similarity score of 0.91
# 'Y desaparece' and 'veramente tua' are similar with a similarity score of 0.91
# 'lo demás' and 'tú estas' are similar with a similarity score of 0.94
# 'lo demás' and 'lo demás' are similar with a similarity score of 1.00
# 'lo demás' and 'tú estas' are similar with a similarity score of 0.94
# 'lo demás' and 'como tú' are similar with a similarity score of 0.92
# 'lo demás' and 'nada más' are similar with a similarity score of 0.91
# 'lo demás' and 'encontré contigo' are similar with a similarity score of 0.91
# 'lo demás' and 'nada más' are similar with a similarity score of 0.91
# 'lo demás' and 'encontré contigo' are similar with a similarity score of 0.91
# 'lo demás' and 'y vida' are similar with a similarity score of 0.91
# 'lo demás' and 'yo consiga' are similar with a similarity score of 0.93
# 'lo demás' and 'y vida' are similar with a similarity score of 0.91
# 'lo demás' and 'yo consiga' are similar with a similarity score of 0.93
# 'lo demás' and 'que quiero' are similar with a similarity score of 0.92
# 'lo demás' and 'mi manera' are similar with a similarity score of 0.93
# 'lo demás' and 'hace dinero' are similar with a similarity score of 0.92
# 'lo demás' and 'y vida' are similar with a similarity score of 0.91
# 'lo demás' and 'yo consiga' are similar with a similarity score of 0.93
# 'lo demás' and 'y vida' are similar with a similarity score of 0.91
# 'lo demás' and 'yo consiga' are similar with a similarity score of 0.93
# 'lo demás' and 'tu chavo' are similar with a similarity score of 0.93
# 'lo demás' and 'es hielo' are similar with a similarity score of 0.95
# 'lo demás' and 'una asesina' are similar with a similarity score of 0.90
# 'lo demás' and 'y vida' are similar with a similarity score of 0.91
# 'lo demás' and 'hice vibrar' are similar with a similarity score of 0.90
# 'lo demás' and 'te lleve' are similar with a similarity score of 0.92
# 'lo demás' and 'hice vibrar' are similar with a similarity score of 0.90
# 'lo demás' and 'bailando sola' are similar with a similarity score of 0.93
# 'lo demás' and 'te lleve' are similar with a similarity score of 0.92
# 'lo demás' and 'a dulce' are similar with a similarity score of 0.90
# 'lo demás' and 'tu ganas' are similar with a similarity score of 0.94
# 'lo demás' and 'como yo' are similar with a similarity score of 0.90
# 'lo demás' and 'como yo' are similar with a similarity score of 0.90
# 'lo demás' and 'hice vibrar' are similar with a similarity score of 0.90
# 'lo demás' and 'te lleve' are similar with a similarity score of 0.92
# 'lo demás' and 'te toco' are similar with a similarity score of 0.94
# 'lo demás' and 'me rozas' are similar with a similarity score of 0.93
# 'lo demás' and 'te excitas' are similar with a similarity score of 0.90
# 'lo demás' and 'te toco' are similar with a similarity score of 0.94
# 'lo demás' and 'me rozas' are similar with a similarity score of 0.93
# 'lo demás' and 'te excitas' are similar with a similarity score of 0.90
# 'lo demás' and 'hice vibrar' are similar with a similarity score of 0.90
# 'lo demás' and 'te lleve' are similar with a similarity score of 0.92
# 'lo demás' and 'hice vibrar' are similar with a similarity score of 0.90
# 'lo demás' and 'bailando sola' are similar with a similarity score of 0.93
# 'lo demás' and 'te lleve' are similar with a similarity score of 0.92
# 'lo demás' and 'se rebeló' are similar with a similarity score of 0.94
# 'lo demás' and 'la invitó' are similar with a similarity score of 0.90
# 'lo demás' and 'que falló' are similar with a similarity score of 0.93
# 'lo demás' and 'se cayó' are similar with a similarity score of 0.93
# 'lo demás' and 'está suelta' are similar with a similarity score of 0.93
# 'lo demás' and 'está suelta' are similar with a similarity score of 0.93
# 'lo demás' and 'la invitó' are similar with a similarity score of 0.90
# 'lo demás' and 'se rebeló' are similar with a similarity score of 0.94
# 'lo demás' and 'se pasa' are similar with a similarity score of 0.93
# 'lo demás' and 'una amenaza' are similar with a similarity score of 0.90
# 'lo demás' and 'es piratea'o' are similar with a similarity score of 0.90
# 'lo demás' and 'está suelta' are similar with a similarity score of 0.93
# 'lo demás' and 'está suelta' are similar with a similarity score of 0.93
# 'lo demás' and 'la invitó' are similar with a similarity score of 0.90
# 'lo demás' and 'se rebeló' are similar with a similarity score of 0.94
# ...
# 'way (Ahh-ahh-ahh)' and 'way (Ahh-ahh-ahh)' are similar with a similarity score of 1.00
# 'way (Ahh-ahh-ahh)' and 'today (Ahh-ahh-ahh)' are similar with a similarity score of 0.91
# 'way (Ahh-ahh-ahh)' and 'go) (Ahh-ahh-ahh)' are similar with a similarity score of 0.91
# 'way (Ahh-ahh-ahh)' and 'way (Ahh-ahh-ahh)' are similar with a similarity score of 1.00
# 'way (Ahh-ahh-ahh)' and 'today (Ahh-ahh-ahh)' are similar with a similarity score of 0.91
# 'way (Ahh-ahh-ahh)' and 'it (Ahh-ahh-ahh)' are similar with a similarity score of 0.94
# 'way (Ahh-ahh-ahh)' and 'it (Ahh-ahh-ahh)' are similar with a similarity score of 0.94
# 'survive today' and 'survive today' are similar with a similarity score of 1.00
# 'survive today' and 'survive today' are similar with a similarity score of 1.00
# 'survive today' and 'survive today' are similar with a similarity score of 1.00
# 'survive today' and 'survive today' are similar with a similarity score of 1.00
# 'survive today' and 'survive today' are similar with a similarity score of 1.00
# 'today (Ahh-ahh-ahh)' and 'it (Ahh-ahh-ahh)' are similar with a similarity score of 0.92
# 'today (Ahh-ahh-ahh)' and 'way (Ahh-ahh-ahh)' are similar with a similarity score of 0.91
# 'today (Ahh-ahh-ahh)' and 'today (Ahh-ahh-ahh)' are similar with a similarity score of 1.00
# 'today (Ahh-ahh-ahh)' and 'way (Ahh-ahh-ahh)' are similar with a similarity score of 0.91
# 'today (Ahh-ahh-ahh)' and 'today (Ahh-ahh-ahh)' are similar with a similarity score of 1.00
# 'today (Ahh-ahh-ahh)' and 'it (Ahh-ahh-ahh)' are similar with a similarity score of 0.92
# 'today (Ahh-ahh-ahh)' and 'it (Ahh-ahh-ahh)' are similar with a similarity score of 0.92
# 'a way' and 'a way' are similar with a similarity score of 1.00
# 'a way' and 'a way' are similar with a similarity score of 1.00
# 'a way' and 'a way' are similar with a similarity score of 1.00
# 'a way' and 'a way' are similar with a similarity score of 1.00
# 'it (Ahh-ahh-ahh)' and 'way (Ahh-ahh-ahh)' are similar with a similarity score of 0.94
# 'it (Ahh-ahh-ahh)' and 'today (Ahh-ahh-ahh)' are similar with a similarity score of 0.92
# 'it (Ahh-ahh-ahh)' and 'go) (Ahh-ahh-ahh)' are similar with a similarity score of 0.92
# 'it (Ahh-ahh-ahh)' and 'way (Ahh-ahh-ahh)' are similar with a similarity score of 0.94
# 'it (Ahh-ahh-ahh)' and 'today (Ahh-ahh-ahh)' are similar with a similarity score of 0.92
# 'it (Ahh-ahh-ahh)' and 'it (Ahh-ahh-ahh)' are similar with a similarity score of 1.00
# 'it (Ahh-ahh-ahh)' and 'it (Ahh-ahh-ahh)' are similar with a similarity score of 1.00
# 'survive today' and 'survive today' are similar with a similarity score of 1.00
# 'survive today' and 'survive today' are similar with a similarity score of 1.00
# 'survive today' and 'survive today' are similar with a similarity score of 1.00
# 'survive today' and 'survive today' are similar with a similarity score of 1.00
# 'go, go)' and 'go, go)' are similar with a similarity score of 1.00
# 'go, go)' and 'go, go)' are similar with a similarity score of 1.00
# 'in (Woo)' and 'untook (Woo)' are similar with a similarity score of 0.90
# '(That's right)' and '(That's right)' are similar with a similarity score of 1.00
# '(That's right)' and '(That's right)' are similar with a similarity score of 1.00
# '(No way)' and '(No way)' are similar with a similarity score of 1.00
# 'let's go)' and 'you're ready)' are similar with a similarity score of 0.91
# 'let's go)' and 'you're ready)' are similar with a similarity score of 0.91
# 'let's go)' and 'come on)' are similar with a similarity score of 0.92
# 'a way' and 'a way' are similar with a similarity score of 1.00
# 'a way' and 'a way' are similar with a similarity score of 1.00
# 'a way' and 'a way' are similar with a similarity score of 1.00
# 'way (Ahh-ahh-ahh)' and 'today (Ahh-ahh-ahh)' are similar with a similarity score of 0.91
# 'way (Ahh-ahh-ahh)' and 'go) (Ahh-ahh-ahh)' are similar with a similarity score of 0.91
# 'way (Ahh-ahh-ahh)' and 'way (Ahh-ahh-ahh)' are similar with a similarity score of 1.00
# 'way (Ahh-ahh-ahh)' and 'today (Ahh-ahh-ahh)' are similar with a similarity score of 0.91
# 'way (Ahh-ahh-ahh)' and 'it (Ahh-ahh-ahh)' are similar with a similarity score of 0.94
# 'way (Ahh-ahh-ahh)' and 'it (Ahh-ahh-ahh)' are similar with a similarity score of 0.94
# 'survive today' and 'survive today' are similar with a similarity score of 1.00
# 'survive today' and 'survive today' are similar with a similarity score of 1.00
# 'survive today' and 'survive today' are similar with a similarity score of 1.00
# 'today (Ahh-ahh-ahh)' and 'way (Ahh-ahh-ahh)' are similar with a similarity score of 0.91
# 'today (Ahh-ahh-ahh)' and 'today (Ahh-ahh-ahh)' are similar with a similarity score of 1.00
# 'today (Ahh-ahh-ahh)' and 'it (Ahh-ahh-ahh)' are similar with a similarity score of 0.92
# 'today (Ahh-ahh-ahh)' and 'it (Ahh-ahh-ahh)' are similar with a similarity score of 0.92
# 'a way' and 'a way' are similar with a similarity score of 1.00
# 'a way' and 'a way' are similar with a similarity score of 1.00
# 'go) (Ahh-ahh-ahh)' and 'way (Ahh-ahh-ahh)' are similar with a similarity score of 0.91
# 'go) (Ahh-ahh-ahh)' and 'it (Ahh-ahh-ahh)' are similar with a similarity score of 0.92
# 'go) (Ahh-ahh-ahh)' and 'it (Ahh-ahh-ahh)' are similar with a similarity score of 0.92
# 'survive today' and 'survive today' are similar with a similarity score of 1.00
# 'survive today' and 'survive today' are similar with a similarity score of 1.00
# 'go, go)' and 'go, go)' are similar with a similarity score of 1.00
# '(That's right)' and '(That's right)' are similar with a similarity score of 1.00
# 'me when)' and 'let me)' are similar with a similarity score of 0.91
# 'me when)' and 'regret me)' are similar with a similarity score of 0.93
# 'me when)' and 'let me)' are similar with a similarity score of 0.91
# 'me when)' and 'girl, now)' are similar with a similarity score of 0.90
# 'me when)' and 'regret me)' are similar with a similarity score of 0.93
# 'me when)' and 'like it)' are similar with a similarity score of 0.91
# 'me when)' and 'like it)' are similar with a similarity score of 0.91
# 'me when)' and 'like it)' are similar with a similarity score of 0.91
# 'me when)' and 'regret me)' are similar with a similarity score of 0.93
# 'a way' and 'a way' are similar with a similarity score of 1.00
# 'way (Ahh-ahh-ahh)' and 'today (Ahh-ahh-ahh)' are similar with a similarity score of 0.91
# 'way (Ahh-ahh-ahh)' and 'it (Ahh-ahh-ahh)' are similar with a similarity score of 0.94
# 'way (Ahh-ahh-ahh)' and 'it (Ahh-ahh-ahh)' are similar with a similarity score of 0.94
# 'survive today' and 'survive today' are similar with a similarity score of 1.00
# 'today (Ahh-ahh-ahh)' and 'it (Ahh-ahh-ahh)' are similar with a similarity score of 0.92
# 'today (Ahh-ahh-ahh)' and 'it (Ahh-ahh-ahh)' are similar with a similarity score of 0.92
# 'it (Ahh-ahh-ahh)' and 'it (Ahh-ahh-ahh)' are similar with a similarity score of 1.00
# 'the music' and 'the music' are similar with a similarity score of 1.00
# 'myself again' and 'myself again' are similar with a similarity score of 1.00
# 'you did' and 'you did' are similar with a similarity score of 1.00
# 'I am' and 'I am' are similar with a similarity score of 1.00
# 'than you' and 'than you' are similar with a similarity score of 1.00
# 'than you' and 'than you' are similar with a similarity score of 1.00
# 'than you' and 'than you' are similar with a similarity score of 1.00
# 'could do' and 'could do' are similar with a similarity score of 1.00
# 'wanted, uh-uh-uh' and 'it, uh-uh-uh' are similar with a similarity score of 0.92
# 'it, uh-uh-uh' and 'it), uh-uh-uh' are similar with a similarity score of 0.91
# 'it, uh-uh-uh' and 'that, uh-uh' are similar with a similarity score of 0.94
# 'it, uh-uh-uh' and 'that, uh-uh' are similar with a similarity score of 0.94
# 'than you' and 'than you' are similar with a similarity score of 1.00
# 'than you' and 'than you' are similar with a similarity score of 1.00
# 'hell, hell' and 'hell, hell' are similar with a similarity score of 1.00
# 'hell, hell' and 'hell, hell' are similar with a similarity score of 1.00
# 'hell, hell' and 'hell, hell' are similar with a similarity score of 1.00
# 'hell, hell' and 'hell, hell' are similar with a similarity score of 1.00
# 'hell, hell' and 'hell, hell' are similar with a similarity score of 1.00
# 'hell, hell' and 'hell, hell' are similar with a similarity score of 1.00
# 'hell, hell' and 'hell, hell' are similar with a similarity score of 1.00
# 'hell, hell' and 'hell, hell' are similar with a similarity score of 1.00
# 'hell, hell' and 'hell, hell' are similar with a similarity score of 1.00
# 'hell, hell' and 'hell, hell' are similar with a similarity score of 1.00
# 'hell, hell' and 'hell, hell' are similar with a similarity score of 1.00
# 'hell, hell' and 'hell, hell' are similar with a similarity score of 1.00
# 'fucking well' and 'fucking well' are similar with a similarity score of 1.00
# 'than you' and 'than you' are similar with a similarity score of 1.00
# 'wanted), uh-uh-uh' and 'it), uh-uh-uh' are similar with a similarity score of 0.94
# 'hell, hell' and 'hell, hell' are similar with a similarity score of 1.00
# 'hell, hell' and 'hell, hell' are similar with a similarity score of 1.00
# 'hell, hell' and 'hell, hell' are similar with a similarity score of 1.00
# 'the rain' and 'the wind' are similar with a similarity score of 0.94
# 'the rain' and 'the lightning' are similar with a similarity score of 0.92
# 'don't know' and 'don't know' are similar with a similarity score of 1.00
# 'the wind' and 'the lightning' are similar with a similarity score of 0.93
# 'my head"' and 'my head"' are similar with a similarity score of 1.00
# ''round here' and ''round here' are similar with a similarity score of 1.00
# ''round here' and ''round here' are similar with a similarity score of 1.00
# ''round here' and ''round here' are similar with a similarity score of 1.00
# ''round here' and ''round here' are similar with a similarity score of 1.00
# ''round here' and ''round here' are similar with a similarity score of 1.00
# ''round here' and ''round here' are similar with a similarity score of 1.00
# 'for me' and 'for me' are similar with a similarity score of 1.00
# 'for me' and 'for me' are similar with a similarity score of 1.00
# 'for me' and 'for me' are similar with a similarity score of 1.00
# 'for me' and 'for me' are similar with a similarity score of 1.00
# 'for me' and 'for me' are similar with a similarity score of 1.00
# 'for me' and 'for me' are similar with a similarity score of 1.00
# 'for me' and 'for me' are similar with a similarity score of 1.00
# 'for me' and 'for me' are similar with a similarity score of 1.00
# 'for me' and 'for me' are similar with a similarity score of 1.00
# 'the universe' and 'the truth' are similar with a similarity score of 0.91
# 'like that' and 'like that' are similar with a similarity score of 1.00
# 'like that' and 'like Tampa' are similar with a similarity score of 0.91
# 'that, uh-uh' and 'that, uh-uh' are similar with a similarity score of 1.00
# 'you're ready)' and 'you're ready)' are similar with a similarity score of 1.00
# 'let me)' and 'regret me)' are similar with a similarity score of 0.92
# 'let me)' and 'let me)' are similar with a similarity score of 1.00
# 'let me)' and 'regret me)' are similar with a similarity score of 0.92
# 'let me)' and 'come on)' are similar with a similarity score of 0.91
# 'let me)' and 'like it)' are similar with a similarity score of 0.92
# 'let me)' and 'like it)' are similar with a similarity score of 0.92
# 'let me)' and 'like it)' are similar with a similarity score of 0.92
# 'let me)' and 'regret me)' are similar with a similarity score of 0.92
# 'in motion' and 'in motion' are similar with a similarity score of 1.00
# 'in motion' and 'in motion' are similar with a similarity score of 1.00
# 'in motion' and 'in motion' are similar with a similarity score of 1.00
# 'in motion' and 'in motion' are similar with a similarity score of 1.00
# 'in motion' and 'in motion' are similar with a similarity score of 1.00
# 'regret me)' and 'let me)' are similar with a similarity score of 0.92
# 'regret me)' and 'regret me)' are similar with a similarity score of 1.00
# 'regret me)' and 'regret me)' are similar with a similarity score of 1.00
# 'in motion' and 'in motion' are similar with a similarity score of 1.00
# 'in motion' and 'in motion' are similar with a similarity score of 1.00
# 'in motion' and 'in motion' are similar with a similarity score of 1.00
# 'in motion' and 'in motion' are similar with a similarity score of 1.00
# 'girl (Girl)' and 'girl (Girl)' are similar with a similarity score of 1.00
# 'girl (Girl)' and 'girl (Girl)' are similar with a similarity score of 1.00
# 'girl (Girl)' and 'girl (Girl)' are similar with a similarity score of 1.00
# '3D (Woo)' and '3D (Woo)' are similar with a similarity score of 1.00
# '3D (Woo)' and '3D (Woo)' are similar with a similarity score of 1.00
# '3D (Woo)' and '3D (Woo)' are similar with a similarity score of 1.00
# '3D (Woo)' and '3D (Woo)' are similar with a similarity score of 1.00
# '3D (Woo)' and '3D (Woo)' are similar with a similarity score of 1.00
# '3D (Woo)' and '3D (Woo)' are similar with a similarity score of 1.00
# 'girl (Girl)' and 'girl (Girl)' are similar with a similarity score of 1.00
# 'girl (Girl)' and 'girl (Girl)' are similar with a similarity score of 1.00
# '3D (Woo)' and '3D (Woo)' are similar with a similarity score of 1.00
# '3D (Woo)' and '3D (Woo)' are similar with a similarity score of 1.00
# '3D (Woo)' and '3D (Woo)' are similar with a similarity score of 1.00
# '3D (Woo)' and '3D (Woo)' are similar with a similarity score of 1.00
# '3D (Woo)' and '3D (Woo)' are similar with a similarity score of 1.00
# 'got it' and 'got those' are similar with a similarity score of 0.90
# 'me started' and 'me crazy' are similar with a similarity score of 0.91
# 'like that' and 'like Tampa' are similar with a similarity score of 0.91
# 'let me)' and 'regret me)' are similar with a similarity score of 0.92
# 'let me)' and 'come on)' are similar with a similarity score of 0.91
# 'let me)' and 'like it)' are similar with a similarity score of 0.92
# 'let me)' and 'like it)' are similar with a similarity score of 0.92
# 'let me)' and 'like it)' are similar with a similarity score of 0.92
# 'let me)' and 'regret me)' are similar with a similarity score of 0.92
# 'in motion' and 'in motion' are similar with a similarity score of 1.00
# 'in motion' and 'in motion' are similar with a similarity score of 1.00
# 'in motion' and 'in motion' are similar with a similarity score of 1.00
# 'regret me)' and 'regret me)' are similar with a similarity score of 1.00
# 'in motion' and 'in motion' are similar with a similarity score of 1.00
# 'in motion' and 'in motion' are similar with a similarity score of 1.00
# 'like it)' and 'like it)' are similar with a similarity score of 1.00
# 'like it)' and 'like it)' are similar with a similarity score of 1.00
# '(Hey; woo)' and '(Woo, woo)' are similar with a similarity score of 0.94
# 'like it)' and 'like it)' are similar with a similarity score of 1.00
# '3D (Woo)' and '3D (Woo)' are similar with a similarity score of 1.00
# '3D (Woo)' and '3D (Woo)' are similar with a similarity score of 1.00
# '3D (Woo)' and '3D (Woo)' are similar with a similarity score of 1.00
# '3D (Woo)' and '3D (Woo)' are similar with a similarity score of 1.00
# '3D (Woo)' and '3D (Woo)' are similar with a similarity score of 1.00
# '3D (Woo)' and '3D (Woo)' are similar with a similarity score of 1.00
# '3D (Woo)' and '3D (Woo)' are similar with a similarity score of 1.00
# 'girl (Girl)' and 'girl (Girl)' are similar with a similarity score of 1.00
# '3D (Woo)' and '3D (Woo)' are similar with a similarity score of 1.00
# '3D (Woo)' and '3D (Woo)' are similar with a similarity score of 1.00
# 'for me' and 'for me' are similar with a similarity score of 1.00
# 'Kook &' and 'Kook &' are similar with a similarity score of 1.00
# 'Jack Harlow' and 'Jack Harlow' are similar with a similarity score of 1.00
# 'in motion' and 'in motion' are similar with a similarity score of 1.00
# '3D (Woo)' and '3D (Woo)' are similar with a similarity score of 1.00

# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# Plotting the cosine similarity matrix
plt.figure(figsize=(10, 8))
sns.heatmap(similarities, xticklabels=last_two_words_list, yticklabels=last_two_words_list, cmap='viridis')
plt.title('Cosine Similarity Heatmap')
plt.xlabel('Text Pairs')
plt.ylabel('Text Pairs')
plt.show()
